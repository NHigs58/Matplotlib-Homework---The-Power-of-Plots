# %% [markdown]
# ## Observations and Insights

# %% [markdown]
# Capumolin and Ramicane seem to be by far the most effective regimens.
#
# The correlation bewteen weight and Tumor Volume is is very high and seems very likely to be a positve correlation between thw two.
#
# None of the top 4 regimens had any outliers which could come from incorrect calculations or they are just very consistent which is a positve sign.

# %% [markdown]
# ## Dependencies and starter code

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import scipy.stats as st
import scipy as sp

# Study data files
mouse_metadata = "data/Mouse_metadata.csv"
study_results = "data/Study_results.csv"

# Read the mouse data and the study results
mouse_metadata = pd.read_csv(mouse_metadata)
study_results = pd.read_csv(study_results)

# Combine the data into a single dataset
combined_data = pd.merge(mouse_metadata, study_results, how = 'left', on = 'Mouse ID')
combined_data.head(20)
# Out:
#    Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 0      k403     Ramicane    Male          21          16          0
# 1      k403     Ramicane    Male          21          16          5
# 2      k403     Ramicane    Male          21          16         10
# 3      k403     Ramicane    Male          21          16         15
# 4      k403     Ramicane    Male          21          16         20
# 5      k403     Ramicane    Male          21          16         25
# 6      k403     Ramicane    Male          21          16         30
# 7      k403     Ramicane    Male          21          16         35
# 8      k403     Ramicane    Male          21          16         40
# 9      k403     Ramicane    Male          21          16         45
# 10     s185    Capomulin  Female           3          17          0
# 11     s185    Capomulin  Female           3          17          5
# 12     s185    Capomulin  Female           3          17         10
# ...

# %% [markdown]
# ## Summary statistics

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen

# %%
#Group by Regimen
regimen_group = combined_data.set_index('Drug Regimen').groupby(['Drug Regimen'])

#Calculations
mean = regimen_group['Tumor Volume (mm3)'].mean()
median = regimen_group['Tumor Volume (mm3)'].median()
variance = regimen_group['Tumor Volume (mm3)'].var()
St_dev = regimen_group['Tumor Volume (mm3)'].std()
sem = regimen_group['Tumor Volume (mm3)'].sem()

summary = pd.DataFrame({"Mean": mean,
                      "Median": median,
                      "Variance": variance,
                      "St Dev": St_dev,
                      "Sem": sem})
summary
# Out:
#                    Mean     Median   Variance    St Dev       Sem
# Drug Regimen
# Capomulin     40.675741  41.557809  24.947764  4.994774  0.329346
# Ceftamin      52.591172  51.776157  39.290177  6.268188  0.469821
# Infubinol     52.884795  51.820584  43.128684  6.567243  0.492236
# Ketapril      55.235638  53.698743  68.553577  8.279709  0.603860
# Naftisol      54.331565  52.509285  66.173479  8.134708  0.596466
# Placebo       54.033581  52.288934  61.168083  7.821003  0.581331
# Propriva      52.322552  50.854632  42.351070  6.507770  0.512884
# Ramicane      40.216745  40.673236  23.486704  4.846308  0.320955
# Stelasyn      54.233149  52.431737  59.450562  7.710419  0.573111
# Zoniferol     53.236507  51.818479  48.533355  6.966589  0.516398

# %% [markdown]
# ## Bar plots

# %%
# Generate a bar plot showing number of data points for each treatment regimen using pandas
treatment_reg = combined_data["Drug Regimen"].value_counts()
treatment_bar_graph = treatment_reg.plot(kind="bar", color="green")

plt.title('Data Points per Regimen')
plt.xlabel('Drug Regimen')
plt.ylabel('Data Points')
# Out:
# Text(0, 0.5, 'Data Points')

# %%
# Generate a bar plot showing number of data points for each treatment regimen using pyplot
tick_locations = [value for value in x_axis]


plt.bar(treatment_reg.index.values, treatment_reg.values, color = 'green', align='center', alpha=0.5)
plt.ylabel('Data Points')
plt.title('Data Points per Regimen')
plt.xlabel('Drug Regimen')

plt.xticks(rotation="vertical")
plt.show()

# %% [markdown]
# ## Pie plots

# %%
# Generate a pie plot showing the distribution of female versus male mice using pandas
gender_count = pd.DataFrame(combined_data["Sex"].value_counts())
gender_df = pd.DataFrame({'count':[958, 935]},
                   index = ['Male', 'Female'])
gender_pie = gender_df.plot.pie(y='count', figsize=(5, 5),autopct="%1.1f%%", shadow=True, startangle=100)

# %%
# Generate a pie plot showing the distribution of female versus male mice using pyplot
gender_count = pd.DataFrame(combined_data["Sex"].value_counts())
labels = ["Male", "Female"]
explode = (0,0)
plt.pie(gender_count, explode=explode, labels=labels, autopct="%1.1f%%", shadow=True, startangle=100)
# Out:
# /Users/nathanhigley/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/ipykernel_launcher.py:5: MatplotlibDeprecationWarning: Non-1D inputs to pie() are currently squeeze()d, but this behavior is deprecated since 3.1 and will be removed in 3.3; pass a 1D array instead.
#   """
# ([<matplotlib.patches.Wedge at 0x1a2118d850>,
# ...
#  [Text(-1.0794459321016996, -0.21165178872169477, 'Male'),
#   Text(1.0794459321016998, 0.21165178872169366, 'Female')],
#  [Text(-0.5887886902372906, -0.1154464302118335, '50.6%'),
#   Text(0.5887886902372907, 0.11544643021183289, '49.4%')])

# %% [markdown]
# ## Quartiles, outliers and boxplots

# %%
# Calculate the final tumor volume of each mouse across four of the most promising treatment regimens. 
top_4 = combined_data.loc[combined_data['Drug Regimen'].isin(["Capomulin", "Ramicane", "Infubinol", "Ceftamin"])
                          &(combined_data['Timepoint'] == 45)]

top_4_group.head()
# Out:
#              Mouse ID     Sex  Age_months  Weight (g)  Timepoint  \
# Drug Regimen
# Ramicane         k403    Male          21          16         45
# Capomulin        s185  Female           3          17         45
# Capomulin        x401  Female          16          15         45
# Capomulin        m601    Male          22          17         45
# Ramicane         g791    Male          11          16         45
# Ramicane         s508    Male           1          17         45
# Ramicane         m546    Male          18          16         45
# Ramicane         z578    Male          11          16         45
# Capomulin        u364    Male          18          17         45
# Capomulin        y793    Male          17          17         45
# Infubinol        a203  Female          20          23         45
# Infubinol        a251  Female          21          25         45
# Ceftamin         a275  Female          20          28         45
# ...

# %%
# Sort data for each regimen for final tumor volume of each mouse
capomulin = combined_data.loc[(combined_data['Drug Regimen'] == "Capomulin") & (combined_data['Timepoint'] == 45)]
ramicane = combined_data.loc[(combined_data['Drug Regimen'] == "Ramicane") & (combined_data['Timepoint'] == 45)]
infubinol = combined_data.loc[(combined_data['Drug Regimen'] == "Infubinol") & (combined_data['Timepoint'] == 45)]
ceftamin = combined_data.loc[(combined_data['Drug Regimen'] == "Ceftamin") & (combined_data['Timepoint'] == 45)]

# %%
# IQR for the top 4 regimens
# Capomulin IQR
volumes = capomulin['Tumor Volume (mm3)']

quartiles = volumes.quantile([.25,.5,.75])
lowerq = quartiles[0.25]
upperq = quartiles[0.75]
iqr = upperq-lowerq

print(f"The lower quartile of Tumor Volumes is: {lowerq}")
print(f"The upper quartile of Tumor Volumes is: {upperq}")
print(f"The interquartile range of Tumor Volumes is: {iqr}")
print(f"The median of Tumor Volumes is: {quartiles[0.5]} ")

lower_bound = lowerq - (1.5*iqr)
upper_bound = upperq + (1.5*iqr)
print(f"Values below {lower_bound} could be outliers.")
print(f"Values above {upper_bound} could be outliers.")
# Out:
# The lower quartile of Tumor Volumes is: 32.37735684
# The upper quartile of Tumor Volumes is: 40.1592203
# The interquartile range of Tumor Volumes is: 7.781863460000004
# The median of Tumor Volumes is: 37.31184577
# Values below 20.70456164999999 could be outliers.
# Values above 51.83201549 could be outliers.

# %%
# Capomulin Outliers
outliers = capomulin.loc[(capomulin['Tumor Volume (mm3)'] > 51.83201549) 
                         & (capomulin['Tumor Volume (mm3)'] < 20.70456164999999)]

outliers.head()
# Out:
# Empty DataFrame
# Columns: [Mouse ID, Drug Regimen, Sex, Age_months, Weight (g), Timepoint, Tumor Volume (mm3), Metastatic Sites]
# Index: []

# %%
# Ramicane IQR
volumes = ramicane['Tumor Volume (mm3)']

quartiles = volumes.quantile([.25,.5,.75])
lowerq = quartiles[0.25]
upperq = quartiles[0.75]
iqr = upperq-lowerq

print(f"The lower quartile of Tumor Volumes is: {lowerq}")
print(f"The upper quartile of Tumor Volumes is: {upperq}")
print(f"The interquartile range of Tumor Volumes is: {iqr}")
print(f"The median of Tumor Volumes is: {quartiles[0.5]} ")

lower_bound = lowerq - (1.5*iqr)
upper_bound = upperq + (1.5*iqr)
print(f"Values below {lower_bound} could be outliers.")
print(f"Values above {upper_bound} could be outliers.")
# Out:
# The lower quartile of Tumor Volumes is: 30.981175224999998
# The upper quartile of Tumor Volumes is: 38.508305307499995
# The interquartile range of Tumor Volumes is: 7.527130082499998
# The median of Tumor Volumes is: 34.848627300000004
# Values below 19.690480101250003 could be outliers.
# Values above 49.79900043124999 could be outliers.

# %%
# Ramicane Outliers
outliers = ramicane.loc[(ramicane['Tumor Volume (mm3)'] > 49.79900043124999) 
                         & (ramicane['Tumor Volume (mm3)'] < 19.690480101250003)]

outliers.head()
# Out:
# Empty DataFrame
# Columns: [Mouse ID, Drug Regimen, Sex, Age_months, Weight (g), Timepoint, Tumor Volume (mm3), Metastatic Sites]
# Index: []

# %%
# Infubinol IQR
volumes = infubinol['Tumor Volume (mm3)']

quartiles = volumes.quantile([.25,.5,.75])
lowerq = quartiles[0.25]
upperq = quartiles[0.75]
iqr = upperq-lowerq

print(f"The lower quartile of Tumor Volumes is: {lowerq}")
print(f"The upper quartile of Tumor Volumes is: {upperq}")
print(f"The interquartile range of Tumor Volumes is: {iqr}")
print(f"The median of Tumor Volumes is: {quartiles[0.5]} ")

lower_bound = lowerq - (1.5*iqr)
upper_bound = upperq + (1.5*iqr)
print(f"Values below {lower_bound} could be outliers.")
print(f"Values above {upper_bound} could be outliers.")
# Out:
# The lower quartile of Tumor Volumes is: 62.75445141
# The upper quartile of Tumor Volumes is: 67.68556862
# The interquartile range of Tumor Volumes is: 4.9311172099999965
# The median of Tumor Volumes is: 66.08306589
# Values below 55.35777559500001 could be outliers.
# Values above 75.08224443499999 could be outliers.

# %%
# Infubinol Outliers
outliers = infubinol.loc[(infubinol['Tumor Volume (mm3)'] > 75.08224443499999) &
                        (infubinol['Tumor Volume (mm3)'] <  55.35777559500001)]

outliers
# Out:
# Empty DataFrame
# Columns: [Mouse ID, Drug Regimen, Sex, Age_months, Weight (g), Timepoint, Tumor Volume (mm3), Metastatic Sites]
# Index: []

# %%
# Ceftamin IQR
volumes = ceftamin['Tumor Volume (mm3)']

quartiles = volumes.quantile([.25,.5,.75])
lowerq = quartiles[0.25]
upperq = quartiles[0.75]
iqr = upperq-lowerq

print(f"The lower quartile of Tumor Volumes is: {lowerq}")
print(f"The upper quartile of Tumor Volumes is: {upperq}")
print(f"The interquartile range of Tumor Volumes is: {iqr}")
print(f"The median of Tumor Volumes is: {quartiles[0.5]} ")

lower_bound = lowerq - (1.5*iqr)
upper_bound = upperq + (1.5*iqr)
print(f"Values below {lower_bound} could be outliers.")
print(f"Values above {upper_bound} could be outliers.")
# Out:
# The lower quartile of Tumor Volumes is: 61.43389223
# The upper quartile of Tumor Volumes is: 67.52748237
# The interquartile range of Tumor Volumes is: 6.093590140000003
# The median of Tumor Volumes is: 64.29983003
# Values below 52.29350701999999 could be outliers.
# Values above 76.66786758 could be outliers.

# %%
# Ceftamin Outliers
outliers = ceftamin.loc[(ceftamin['Tumor Volume (mm3)'] > 76.66786758) 
                         & (ceftamin['Tumor Volume (mm3)'] <  52.29350701999999)]

outliers.head()
# Out:
# Empty DataFrame
# Columns: [Mouse ID, Drug Regimen, Sex, Age_months, Weight (g), Timepoint, Tumor Volume (mm3), Metastatic Sites]
# Index: []

# %%
# Generate a box plot of the final tumor volume of each mouse across four regimens of interest
outliers = dict(markerfacecolor = "red", markersize = 12)


Volume = capomulin['Tumor Volume (mm3)']
fig1, ax1 = plt.subplots()
ax1.set_title('Final Tumor Volume Capomulin')
ax1.set_ylabel('Tumor Volume (mm3)')
ax1.boxplot(Volume, flierprops = outliers)

Volume = ramicane['Tumor Volume (mm3)']
fig1, ax1 = plt.subplots()
ax1.set_title('Final Tumor Volume Ramicane')
ax1.set_ylabel('Tumor Volume (mm3)')
ax1.boxplot(Volume, flierprops = outliers)

Volume = infubinol['Tumor Volume (mm3)']
fig1, ax1 = plt.subplots()
ax1.set_title('Final Tumor Volume Infubinol')
ax1.set_ylabel('Tumor Volume (mm3)')
ax1.boxplot(Volume, flierprops = outliers)

Volume = ceftamin['Tumor Volume (mm3)']
fig1, ax1 = plt.subplots()
ax1.set_title('Final Tumor Volume Ceftamin')
ax1.set_ylabel('Tumor Volume (mm3)')
ax1.boxplot(Volume, flierprops = outliers)


plt.show()

# %% [markdown]
# ## Line and scatter plots

# %%
# Generate a line plot of time point versus tumor volume for a mouse treated with Capomulin
cap = combined_data.loc[(combined_data['Drug Regimen'] == "Capomulin")& (combined_data['Mouse ID'] == 'l509')]
time = cap['Timepoint']
volume = cap['Tumor Volume (mm3)']
cap

df_capomulin = pd.DataFrame(
    {'Time Point': time, 'Tumor Volume': volume})

plt.title('Time point versus Tumor volume')
plt.xlabel('Time Point')
plt.ylabel('Tumor Volume (mm3)')

df_capomulin.set_index('Time Point')['Tumor Volume'].plot()

# %%
# Out:
#    Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 10     s185    Capomulin  Female           3          17          0
# 11     s185    Capomulin  Female           3          17          5
# 12     s185    Capomulin  Female           3          17         10
# 13     s185    Capomulin  Female           3          17         15
# 14     s185    Capomulin  Female           3          17         20
# 15     s185    Capomulin  Female           3          17         25
# 16     s185    Capomulin  Female           3          17         30
# 17     s185    Capomulin  Female           3          17         35
# 18     s185    Capomulin  Female           3          17         40
# 19     s185    Capomulin  Female           3          17         45
#
#     Tumor Volume (mm3)  Metastatic Sites
# 10           45.000000                 0
# 11           43.878496                 0
# 12           37.614948                 0
# 13           38.177232                 0
# ...

# %%
# Generate a scatter plot of mouse weight versus average tumor volume for the Capomulin regimen
capomulin.head()
mice = capomulin.set_index('Mouse ID').groupby(['Mouse ID'])
avg_tumor = mice['Tumor Volume (mm3)'].mean()
weight = mice["Weight (g)"].median()
scatter = pd.DataFrame ({
    "Average Tumor":avg_tumor,
    "Weight":weight
})

plt.scatter(weight, avg_tumor, marker="o", facecolors="green", edgecolors="black",
            s=x_axis, alpha=0.75)
plt.title("Weight vs Avg Tumor Volume")
plt.xlabel('Weight')
plt.ylabel('Tumor Volume (mm3)')
# Out:
# Text(0, 0.5, 'Tumor Volume (mm3)')

# %%
# Calculate the correlation coefficient and linear regression model for mouse weight and average tumor volume for the Capomulin regimen
correlation = st.pearsonr(weight,avg_tumor)
print(f"The correlation between both factors is {round(correlation[0],2)}")
plt.show()
# Out:
# The correlation between both factors is 0.84
